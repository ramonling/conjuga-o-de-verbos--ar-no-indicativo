# %%
verbo = input("Nome do Verbo= ")
eu = verbo.rstrip("ar") + "o"
tu = verbo.rstrip("ar") + "as"
ele = verbo.rstrip("ar") + "a"
nós = verbo.rstrip("ar") + "amos"
vós = verbo.rstrip("ar") + "ais"
eles = verbo.rstrip("ar") + "am"
print("\033[1mPresente do indicativo\033[0m")
print(" ")
print(f"Eu " + eu)
print(f"Tu " + tu)
print(f"Ele " + ele)
print(f"Nós " + nós)
print(f"Vós " + vós)
print(f"Eles " + eles)
print(" ")
print("\033[1mPretérito imperfeito do indicativo\033[0m")
print(" ")
eu = verbo.rstrip("ar") + "ava"
tu = verbo.rstrip("ar") + "avas"
ele = verbo.rstrip("ar") + "ava"
nós = verbo.rstrip("ar") + "ávamos"
vós = verbo.rstrip("ar") + "áveis"
eles = verbo.rstrip("ar") + "avam"
print(f"Eu " + eu)
print(f"Tu " + tu)
print(f"Ele " + ele)
print(f"Nós " + nós)
print(f"Vós " + vós)
print(f"Eles " + eles)
print(" ")
print("\033[1mPretérito perfeito do indicativo\033[0m")
print(" ")
eu = verbo.rstrip("ar") + "ei"
tu = verbo.rstrip("ar") + "aste"
ele = verbo.rstrip("ar") + "ou"
nós = verbo.rstrip("ar") + "amos"
vós = verbo.rstrip("ar") + "astes"
eles = verbo.rstrip("ar") + "aram"
print(f"Eu " + eu)
print(f"Tu " + tu)
print(f"Ele " + ele)
print(f"Nós " + nós)
print(f"Vós " + vós)
print(f"Eles " + eles)
print(" ")
print("\033[1mPretérito mais-que-perfeito do indicativo\033[0m")
print(" ")
eu = verbo.rstrip("ar") + "ara"
tu = verbo.rstrip("ar") + "aras"
ele = verbo.rstrip("ar") + "ara"
nós = verbo.rstrip("ar") + "áramos"
vós = verbo.rstrip("ar") + "áres"
eles = verbo.rstrip("ar") + "aram"
print(f"Eu " + eu)
print(f"Tu " + tu)
print(f"Ele " + ele)
print(f"Nós " + nós)
print(f"Vós " + vós)
print(f"Eles " + eles)
print(" ")
print("\033[1mFuturo do presente do indicativo\033[0m")
print(" ")
eu = verbo.rstrip("ar") + "arei"
tu = verbo.rstrip("ar") + "arás"
ele = verbo.rstrip("ar") + "ará"
nós = verbo.rstrip("ar") + "aremos"
vós = verbo.rstrip("ar") + "areis"
eles = verbo.rstrip("ar") + "arão"
print(f"Eu " + eu)
print(f"Tu " + tu)
print(f"Ele " + ele)
print(f"Nós " + nós)
print(f"Vós " + vós)
print(f"Eles " + eles)
print(" ")
print("\033[1mFuturo do pretérito do indicativo\033[0m")
print(" ")
eu = verbo.rstrip("ar") + "aria"
tu = verbo.rstrip("ar") + "arias"
ele = verbo.rstrip("ar") + "aria"
nós = verbo.rstrip("ar") + "ariamos"
vós = verbo.rstrip("ar") + "aríeis"
eles = verbo.rstrip("ar") + "ariam"
print(f"Eu " + eu)
print(f"Tu " + tu)
print(f"Ele " + ele)
print(f"Nós " + nós)
print(f"Vós " + vós)
print(f"Eles " + eles)

# %% [markdown]
# .rstrip("ar") utilizei para retirar as duas últimas letras do verbo
#
# \033[1m nome do texto \033[0m utilizei para deixar o texto em negrito (o uso do "**" não funcionou)
